# %% [markdown]
# ## 취지 설명
#
# ### 1. 배경
#
# 최근 인류에게 다가온 빅데이터라는 단어는 우주와 천문학에게 낯설지 않습니다.
#
# 찰나의 순간에도 우주는 천문학적인 양의 데이터를 생산해왔고, 오래 전부터 천문학자들은 우주를 관측했으며, 그 방대함에 비례하는 데이터를 수집 및 분석했기 때문입니다.
#
# 슬론 디지털 천체 관측(Sloan Digital Sky Survey: 이하 SDSS)는 세계적 천체 관측 프로젝트로, 우주에 대한 천문학적인 규모의 데이터를 수집하고 있습니다.
#
# 이곳에서 수집한 데이터는 약 6,000개 논문에 사용되었고, 25만 회 이상 인용되었을 정도로 천문학에 큰 기여를 했습니다.
#
# 점점 거대해지는 규모에 따라 데이터 처리에는 머신러닝과 딥러닝 기법이 활용되기 시작했습니다.
#
# 여전히 우주에는 다양한 미지의 이야기가 남아있고, 오늘날 인간은 하늘에서 많은 데이터를 얻어낼 정도로 발전했습니다.
#
# 이 데이터를 분석하여 어쩌면 드러나지 않은 규칙이 여러분의 손끝에서 밝혀질 수 있습니다.
#
# 새로운 알고리즘을 통해 우주의 비밀을 찾아주세요!
#
#
# #### 2. 대회 Stage 안내 :
# Free Stage → Regular StageⅠ → Regular Stage Ⅱ → Final Stage
#
# - 자세한 사항은 대회 일정을 참고해주세요.
#
#
# ## 데이터 설명
#
# 대회에서 제공하는 데이터는 천체의 관측 정보를 담고 있습니다. 이 데이터를 사용하여 천체의 유형을 분류합니다
#
# Point spread function magnitudes : 먼 천체를 한 점으로 가정하여 측정한 빛의 밝기입니다.
#
# Fiber magnitudes : 3인치 지름의 광섬유를 사용하여 광스펙트럼을 측정합니다. 광섬유를 통과하는 빛의 밝기입니다.
#
# Petrosian Magnitudes : 은하처럼 뚜렷한 표면이 없는 천체에서는 빛의 밝기를 측정하기 어렵습니다. 천체의 위치와 거리에 상관없이 빛의 밝기를 비교하기 위한 수치입니다.
#
# Model magnitudes : 천체 중심으로부터 특정 거리의 밝기입니다.
#
# fiber id : 관측에 사용된 광섬유의 구분자
#
# 'id' : ID
# 'type' : Target
# 'fiberID' : 광섬유의 종류
#     __몇가지나 있을까?__
# 'psfMag_u' : 먼 천체를 한 점으로 가정하여 측정한 빛 ultraviolet 밝기
# 'psfMag_g' : 먼 천체를 한 점으로 가정하여 측정한 빛 Green 밝기
# 'psfMag_r' : 먼 천체를 한 점으로 가정하여 측정한 빛 Red 밝기
# 'psfMag_i' : 먼 천체를 한 점으로 가정하여 측정한 빛 Near Infrared 밝기
#     __Near infrared 와 infrared 의 차이???__
# 'psfMag_z' : 먼 천체를 한 점으로 가정하여 측정한 빛 Infrared 밝기
# 'fiberMag_u' : 3인치 지름의 광섬유를 사용하여 광스펙트럼을 측정합니다. 광섬유를 통과하는 ultraviolet의 밝기입니다. fiberID는 fiberMag와만 관련이 있다고 말할 수 없습니다.
# 'fiberMag_g' : 3인치 지름의 광섬유를 사용하여 광스펙트럼을 측정합니다. 광섬유를 통과하는 Green빛의 밝기입니다. fiberID는 fiberMag와만 관련이 있다고 말할 수 없습니다.
# 'fiberMag_r' : 3인치 지름의 광섬유를 사용하여 광스펙트럼을 측정합니다. 광섬유를 통과하는 Red빛의 밝기입니다. fiberID는 fiberMag와만 관련이 있다고 말할 수 없습니다.
# 'fiberMag_i' : 3인치 지름의 광섬유를 사용하여 광스펙트럼을 측정합니다. 광섬유를 통과하는 Near Infrared 빛의 밝기입니다. fiberID는 fiberMag와만 관련이 있다고 말할 수 없습니다.
# 'fiberMag_z' : 3인치 지름의 광섬유를 사용하여 광스펙트럼을 측정합니다. 광섬유를 통과하는 Infrared 빛의 밝기입니다. fiberID는 fiberMag와만 관련이 있다고 말할 수 없습니다.
#     __밝기 측정방법??: 모든 측정방법에 광섬유가 쓰이나??__
# 'petroMag_u' : 은하처럼 뚜렷한 표면이 없는 천체에서는 빛의 밝기를 측정하기 어렵습니다. 천체의 위치와 거리에 상관없이 ultraviolet의 밝기를 비교하기 위한 수치입니다.
# 'petroMag_g' : 은하처럼 뚜렷한 표면이 없는 천체에서는 빛의 밝기를 측정하기 어렵습니다. 천체의 위치와 거리에 상관없이 Green의 밝기를 비교하기 위한 수치입니다.
# 'petroMag_r' : 은하처럼 뚜렷한 표면이 없는 천체에서는 빛의 밝기를 측정하기 어렵습니다. 천체의 위치와 거리에 상관없이 Red 빛의 밝기를 비교하기 위한 수치입니다.
# 'petroMag_i' : 은하처럼 뚜렷한 표면이 없는 천체에서는 빛의 밝기를 측정하기 어렵습니다. 천체의 위치와 거리에 상관없이 Near Infrared 빛의 밝기를 비교하기 위한 수치입니다.
# 'petroMag_z' : 은하처럼 뚜렷한 표면이 없는 천체에서는 빛의 밝기를 측정하기 어렵습니다. 천체의 위치와 거리에 상관없이 Infrared 빛의 밝기를 비교하기 위한 수치입니다.
# 'modelMag_u' : 천체 중심으로부터 특정 거리의 ultraviolet 밝기입니다.
# 'modelMag_g' : 천체 중심으로부터 특정 거리의 Green 밝기입니다.
# 'modelMag_r' : 천체 중심으로부터 특정 거리의 Red 밝기입니다.
# 'modelMag_i' : 천체 중심으로부터 특정 거리의 Near Infrared 밝기입니다.
# 'modelMag_z' : 천체 중심으로부터 특정 거리의 Infrared 밝기입니다.
#     __각각 측정방법의 차이를 변수로 만든다면??__
#
# #### 평가
#
# 본 대회에서는 LogLoss로 제출 파일을 평가합니다.
#
# a) 가채점 순위 : 대회 중 test 데이터의 30%로 채점합니다.
#
# b) 최종 순위 : 가채점에서 사용하지 않은 나머지 test 데이터로 채점합니다. 대회 종료 후에 공개됩니다.
#
# 최종순위는 참가자가 선택한 파일로 채점되므로, 참가자는 자신이 채점 받고 싶은 제출 파일을 최종적으로 선택해야 합니다.
#
# ####  대회 Stage 기간 안내 :﻿﻿﻿﻿﻿﻿﻿﻿﻿﻿﻿﻿﻿﻿﻿﻿﻿﻿﻿﻿﻿﻿﻿
#
# Free Stage(2월 1일 10:00 ~ 2월 21일 23:59)
#
# 위 기간에서 Baseline_1 코드 랭킹보다 높은 참가자만 Regular StageⅠ에 참가할 수 있습니다.
#
#
#
# Regular StageⅠ(2월 22일 00:00 ~ 2월 23일 23:59)
#
# 위 기간에서 Baseline_2 코드 랭킹보다 높은 참가자만 Regular StageⅡ에 참가할 수 있습니다.
#
#
#
# Regular Stage Ⅱ(2월 24일 00:00 ~ 2월 25일 23:59)
#
# 위 기간에서 상위 랭킹 50% 참가자만 Final Stage에 참가할 수 있습니다.
#
#
#
# Final Stage(2월 26일 00:00 ~ 2월 29일 23:59)
#
# 최종 랭킹이 결정됩니다.

# %%
import pandas as pd
import numpy as np

import dill as pickle
import os

import matplotlib.pyplot as plt
import seaborn as sns

from CB_utils import *

# %%
with open("input/data_raw.pkl", "rb") as f:
    data = pickle.load(f)

train = data["train"]
test = data["test"]

# %%
TARGET = "type"

# %%
train_info = load_eda_statistic_pd("eda/tr_profile,pkl", train)
test_info = load_eda_statistic_pd("eda/te_profile,pkl", test)

# %%
print(train_info["dim"],"\n", test_info["dim"])
# Out:
# (199991, 23)
#  (10009, 22)

# %%
train_info["describe"]
# Out:
#                   id    type        fiberID      psfMag_u       psfMag_g  \
# count   199991.00000  199991  199991.000000  1.999910e+05  199991.000000
# unique           NaN      19            NaN           NaN            NaN
# top              NaN     QSO            NaN           NaN            NaN
# freq             NaN   49680            NaN           NaN            NaN
# mean     99995.00000     NaN     360.830152 -6.750146e+00      18.675373
# std      57732.57318     NaN     225.305890  1.187678e+04     155.423024
# min          0.00000     NaN       1.000000 -5.310802e+06  -40022.466071
# 25%      49997.50000     NaN     174.000000  1.965259e+01      18.701180
# 50%      99995.00000     NaN     349.000000  2.087136e+01      19.904235
# 75%     149992.50000     NaN     526.000000  2.216043e+01      21.150297
# max     199990.00000     NaN    1000.000000  1.877392e+04    3538.984910
#
#              psfMag_r       psfMag_i       psfMag_z    fiberMag_u  \
# ...

# %%
test_info["describe"]
# Out:
#                   id       fiberID      psfMag_u      psfMag_g      psfMag_r  \
# count   10009.000000  10009.000000  10009.000000  10009.000000  10009.000000
# mean   204995.000000    359.327805     20.987400     19.878440     19.280218
# std      2889.493756    223.928862      2.111703      2.573890      1.709344
# min    199991.000000      1.000000     -7.248195    -42.663871      9.134712
# 25%    202493.000000    174.000000     19.655525     18.671025     18.037847
# 50%    204995.000000    346.000000     20.854404     19.910333     19.444925
# 75%    207497.000000    525.000000     22.160801     21.150040     20.489912
# max    209999.000000   1000.000000     37.681143    182.654452     31.883768
#
#            psfMag_i      psfMag_z    fiberMag_u    fiberMag_g    fiberMag_r  \
# count  10009.000000  10009.000000  10009.000000  10009.000000  10009.000000
# mean      18.873165     18.618385     21.184506     20.091376     19.497732
# ...

# %% [markdown]
# ### describe
# fiberID 1000개

# %%
#train_info["isnull_table"]

# %%
#test_info["isnull_table"]

# %% [markdown]
# ### ISNULL
# 결측치 X

# %%
train.duplicated().sum()
# Out:
# 0

# %%
test.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Duplicated
# 동일한 열 없음

# %% [markdown]
# ### Y분석

# %%
train_info["value_counts"]["type"]
# Out:
# QSO                    49680
# GALAXY                 37347
# SERENDIPITY_BLUE       21760
# SPECTROPHOTO_STD       14630
# REDDEN_STD             14618
# STAR_RED_DWARF         13750
# STAR_BHB               13500
# SERENDIPITY_FIRST       7132
# ROSAT_D                 6580
# STAR_CATY_VAR           6506
# SERENDIPITY_DISTANT     4654
# STAR_CARBON             3257
# SERENDIPITY_RED         2562
# STAR_WHITE_DWARF        2160
# STAR_SUB_DWARF          1154
# STAR_BROWN_DWARF         500
# SKY                      127
# SERENDIPITY_MANUAL        61
# STAR_PN                   13
# Name: type, dtype: int64

# %% [markdown]
# 'QSO' :
# 'GALAXY'
# 'SERENDIPITY_BLUE'
# 'SPECTROPHOTO_STD'
# 'REDDEN_STD':
# 'STAR_RED_DWARF'
# 'STAR_BHB'
# 'SERENDIPITY_FIRST'
# 'ROSAT_D'
# 'STAR_CATY_VAR'
# 'SERENDIPITY_DISTANT'
# 'STAR_CARBON',
# 'SERENDIPITY_RED'
# 'STAR_WHITE_DWARF'
# 'STAR_SUB_DWARF'
# 'STAR_BROWN_DWARF'
# 'SKY'
# 'SERENDIPITY_MANUAL'
# 'STAR_PN'

# %% [markdown]
# ### Test 와 Train 의 분포가 일치하는지 확인
# - 적은 수의 feature 이므로 그래프를 통해 확인
# - pair plot?

# %%
with open("input/data_outlierRemove.pkl", "rb") as f:
    data = pickle.load(f)

train = data["train"]
test = data["test"]

# %%
train = train.drop("type", axis =1)

# %%
train["test"] = 0
test["test"] = 1

# %%
total = pd.concat([train, test], axis = 0)

# %%
features = total.columns[1:]

# %% [markdown]
# ### Test 와 Train 의 Distplot
#
# 1. train 에서 대부분의 column 들이 굉장히 작은값을 가지고 있는 경우가 많음(outlier) ex) -4000000
#     - 밝기에서 - 값은 무엇을 의미?? : 더 밝다는 것을 의미한다
#     - 후보 1 : -40000 만큼 밝던 -400만큼 밝던 그냥 밝은 것을 의미하기 때문에 test 데이터의 최소값 - 1으로 encoding한다
#     - 후보 2 : test 데이터의 범위에 없으면 지워버린다
#     - 후보 3 : Boxplot 의 outlier 검출법을 통해 지워버린다

# %%
def plot_feature_distribution(df, features, target = None, save = False, filename =  "",params = {}):
    """
    feature들의 histogram 그려주는 함수
    argument:
        df - (pd.dataframe) DataFrame
        features - 그릴 feature 들
    """
    GRID = 5
    if target != None:
        ntarget = df[target].value_counts().keys().values #(string np.array) target feature의 class 확인
        subdf = [df.loc[df[target] == label] for label in ntarget] #(df list) df grouped by target, ntarget key 순서
    i = 0
    plt.figure()
    fig, ax = plt.subplots(GRID,GRID,figsize=(24,30))

    for feature in features:
        i += 1
        plt.subplot(GRID,GRID,i)
        if target != None:
            for _i,label in enumerate(ntarget):
                sns.distplot(subdf[_i][feature], hist=True,label=label,**params)
        else:
            sns.distplot(df[feature], hist=True, **params)
        plt.xlabel(feature, fontsize=9)
        locs, labels = plt.xticks()
        plt.tick_params(axis='x', which='major', labelsize=13, pad=0)
        plt.tick_params(axis='y', which='major', labelsize=10)
        #plt.legend()
    if save == True:
        plt.savefig(filename)

# %%
#plot_feature_distribution(total, features, target = "test", save = True, filename = "eda/distplot/total.png")

# %%
#plot_feature_distribution(train, features, target = "test", save = True, filename = "eda/distplot/train.png")

# %%
#plot_feature_distribution(test, features, target = "test", save = True, filename = "eda/distplot/test.png", params = {"color" : "peru"})

# %%
sns.boxplot(train[features[2]])

# %% [markdown]
# **Point spread function magnitudes : 먼 천체를 한 점으로 가정하여 측정한 빛의 밝기입니다. 마다 u,g,r,i,z 의 pair plot**

# %% [markdown]
# Point spread function magnitudes : 먼 천체를 한 점으로 가정하여 측정한 빛의 밝기입니다.
#
# Fiber magnitudes : 3인치 지름의 광섬유를 사용하여 광스펙트럼을 측정합니다. 광섬유를 통과하는 빛의 밝기입니다.
#
# Petrosian Magnitudes : 은하처럼 뚜렷한 표면이 없는 천체에서는 빛의 밝기를 측정하기 어렵습니다. 천체의 위치와 거리에 상관없이 빛의 밝기를 비교하기 위한 수치입니다.
#
# Model magnitudes : 천체 중심으로부터 특정 거리의 밝기입니다.
#
# fiber id : 관측에 사용된 광섬유의 구분자
#
# 이거마다 서로의 pair plot 보기
#
# violet, green, red, nearinfrared, infrared 마다 pair plot 보기

# %%
total.dtypes
# Out:
# id              int64
# fiberID         int64
# psfMag_u      float64
# psfMag_g      float64
# psfMag_r      float64
# psfMag_i      float64
# psfMag_z      float64
# fiberMag_u    float64
# fiberMag_g    float64
# fiberMag_r    float64
# fiberMag_i    float64
# fiberMag_z    float64
# petroMag_u    float64
# petroMag_g    float64
# petroMag_r    float64
# petroMag_i    float64
# petroMag_z    float64
# modelMag_u    float64
# modelMag_g    float64
# modelMag_r    float64
# modelMag_i    float64
# modelMag_z    float64
# test            int64
# dtype: object

# %%
sns.pairplot(total[['psfMag_u', 'psfMag_g', 'psfMag_r', 'psfMag_i','psfMag_z',"test"]], hue = "test")
# Out:
# C:\Users\ghdbs\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\ghdbs\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
train[train.columns[1:-1]].corr()
# Out:
#              fiberID  psfMag_u  psfMag_g  psfMag_r  psfMag_i  psfMag_z  \
# fiberID     1.000000  0.072072  0.107081  0.150441  0.185604  0.192331
# psfMag_u    0.072072  1.000000  0.870850  0.751577  0.550844  0.394261
# psfMag_g    0.107081  0.870850  1.000000  0.925191  0.763429  0.614617
# psfMag_r    0.150441  0.751577  0.925191  1.000000  0.913762  0.806948
# psfMag_i    0.185604  0.550844  0.763429  0.913762  1.000000  0.956668
# psfMag_z    0.192331  0.394261  0.614617  0.806948  0.956668  1.000000
# fiberMag_u  0.077247  0.943859  0.875126  0.761444  0.564082  0.405982
# fiberMag_g  0.114296  0.866617  0.967787  0.935003  0.771993  0.621689
# fiberMag_r  0.156935  0.724112  0.907315  0.980087  0.902360  0.797658
# fiberMag_i  0.193463  0.521073  0.745439  0.902388  0.975737  0.944826
# fiberMag_z  0.196022  0.362859  0.595178  0.793839  0.940291  0.967052
# petroMag_u  0.083366  0.752735  0.715663  0.641096  0.482230  0.363608
# ...

# %%
plt.figure(figsize=(25,25))
sns.heatmap(train[train.columns[1:-1]].corr(), cmap="RdYlBu_r");

# %%
from sklearn.model_selection import train_test_split,StratifiedKFold
from sklearn.metrics import log_loss,roc_auc_score


SEED = 42
target = "test"

X_train, X_valid, y_train, y_valid = train_test_split(train[features], train[target], test_size=0.2, random_state=SEED)

trn_data = Pool(data = X_train, label = y_train)
val_data = Pool(data = X_valid, label = y_valid)

params = {"iterations" : 1000}
    
model = CatBoostClassifier(**params,
                           random_seed = SEED,
                           task_type="GPU")

fit_model = model.fit(trn_data,
                     eval_set = val_data,
                     use_best_model = True,
                     verbose = 100,
                     plot = False)

p_valid = fit_model.predict_proba(X_valid)
yp = fit_model.predict_proba(test[features])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-17aad54a5785> in <module>
#      12     X_train, y_train = train.iloc[trn_idx][features], train.iloc[trn_idx][target]
#      13     X_valid, y_valid = train.iloc[val_idx][features], train.iloc[val_idx][target]
# ---> 14     trn_data = Pool(X_train, label=y_train)
#      15     val_data = Pool(X_valid, label=y_valid)
#      16
#
# NameError: name 'Pool' is not defined

# %%
feature_importance["feature"] = features
feature_importance["importance"] = model.get_feature_importance(val_data,type='LossFunctionChange')
print(f'log_loss: {logloss:.5}')

# %%
cols = feature_importance[["feature", "importance"]].groupby("feature").mean().sort_values(
        by="importance", ascending=False)[:100].index
best_features = feature_importance.loc[feature_importance.feature.isin(cols)]
plt.figure(figsize=(20, 30));
sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False));
plt.title('Catboost Importance');
plt.show()
